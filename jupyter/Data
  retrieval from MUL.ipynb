# %% [markdown]
# # Data retrieval from MUL site for Mech Assist application
# This code retrieves the whole list of units from http://masterunitlist.info/ and their Alpha Strike parameters.
#
# Note: code was done with chatGPT asistance

# %%
import requests
from bs4 import BeautifulSoup
import csv
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime
import time
import pandas as pd
from tqdm.auto import tqdm
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# %%
retry = Retry(
    total=3,
    backoff_factor=1,       # waits 1s, 2s, 4s between retries
    status_forcelist=[429, 500, 502, 503, 504],
)
adapter = HTTPAdapter(max_retries=retry)
session = requests.Session()
session.mount('http://', adapter)
session.mount('https://', adapter)

# %% [markdown]
# Define the URL

# %%
# Define the URL for ALL units (mechs, vehicles, infantry, aerospace, buildings, etc)
search_url = "http://www.masterunitlist.info/Unit/Filter?Types=18&Types=19&Types=17&Types=21&Types=20&Types=23&Types=24&Types=81&Types=79&Types=97&Types=76"

# %% [markdown]
# Connect and get confirmation of connection

# %%
# Send an HTTP GET request to the URL
response = session.get(search_url, timeout=30)
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    print("Access granted!")
else:
    print("Failed to retrieve the webpage.")
# Out:
# Access granted!

# %% [markdown]
# Make a list of all mechs

# %%
# Find all units
unit_names = [
    a.text for a in soup.find_all('a', href=True) if a['href'].startswith("/Unit/Details/")
]

# %% [markdown]
# Make a dataframe to collect units parameters

# %%
dataset = pd.DataFrame(columns = ["Name", "Class", "Variant", "Role", "PV", "Type", "Size", "Move",\
                  "Short", "ShortMin", "Medium", "MediumMin", "Long", "LongMin", "Extreme", "ExtremeMin", "Threshold",\
                  "Overheat", "Armor", "Structure", "Specials", "ImageURL"])

# %% [markdown]
# Fill `dataset` with units' information:

# %%
MECH_TYPES = ["BM", "IM", "PM"]
AEROSPACE_TYPES = ["AF", "CF"]

for i, unit_name in enumerate(unit_names):
    unit_trail = unit_name.replace("+","%2b")
    if (i%50 == 0):
        percent_complete = (i + 1) / len(unit_names) * 100
        print(f"Parsing {i + 1} of {len(unit_names)} units - {percent_complete:.2f}% complete")

    # Define the URL with the query parameters
    url = f"https://masterunitlist.azurewebsites.net/Unit/QuickList?Name={unit_trail}"
    
    # Send an HTTP GET request with the parameters
    response = session.get(url, timeout=30, stream=True)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:

        # Parse the JSON response
        data = response.json()

        # Identify which unit should be parsed as one request may return several units. For example:
        # https://masterunitlist.azurewebsites.net/Unit/QuickList?Name=Phoenix%20Hawk%20PXH-1k

        for item in data.get("Units"):
            if (item.get("Name")==unit_name):
                index = data.get("Units").index(item)

        # Extract the desired information
        parsed_unit = {
            "Name": data.get("Units")[index].get("Name"),
            "Class": data.get("Units")[index].get("Class"),
            "Variant": data.get("Units")[index].get("Variant"),
            "Role": data.get("Units")[index].get("Role").get("Name"),
            "PV": data.get("Units")[index].get("BFPointValue", 0),
            "Type": data.get("Units")[index].get("BFType", ""),
            "Size": data.get("Units")[index].get("BFSize", 0),
            "Move": data.get("Units")[index].get("BFMove", ""),
            "Short": data.get("Units")[index].get("BFDamageShort", 0),
            "ShortMin": data.get("Units")[index].get("BFDamageShortMin", 0),
            "Medium": data.get("Units")[index].get("BFDamageMedium", 0),
            "MediumMin": data.get("Units")[index].get("BFDamageMediumMin", 0),
            "Long": data.get("Units")[index].get("BFDamageLong", 0),
            "LongMin": data.get("Units")[index].get("BFDamageLongMin", 0),
            "Armor": data.get("Units")[index].get("BFArmor", 0),
            "Structure": data.get("Units")[index].get("BFStructure", 0),
            "Specials": data.get("Units")[index].get("BFAbilities", ""),
            "ImageURL": data.get("Units")[index].get("ImageUrl", "")
        }
        if parsed_unit["Type"] in MECH_TYPES:
            parsed_unit["Overheat"] = data.get("Units")[index].get("BFOverheat", 0)
        else:
            parsed_unit["Overheat"] = 0

        #REGARDING AEROSPACE: note the inconsistent errors on the API side for "Exteme"
        if parsed_unit["Type"] in AEROSPACE_TYPES:
            parsed_unit["Extreme"] = data.get("Units")[index].get("BFDamageExtreme", 0)
            parsed_unit["ExtremeMin"] = data.get("Units")[index].get("BFDamageExtemeMin", 0)
            parsed_unit["Threshold"] = data.get("Units")[index].get("BFThreshold", 0)
        else:
            parsed_unit["Extreme"] = 0
            parsed_unit["ExtremeMin"] = False
            parsed_unit["Threshold"] = 0
        
        # Add unit parameters to the dataframe
        dataset = pd.concat([dataset, pd.DataFrame([parsed_unit])], ignore_index=True)

    time.sleep(0.1)

print(f"Data has been saved to 'datase' DataFrame")
# Out:
# Parsing 1 of 8710 units - 0.01% complete
# Parsing 51 of 8710 units - 0.59% complete
# Parsing 101 of 8710 units - 1.16% complete
# Parsing 151 of 8710 units - 1.73% complete
# Parsing 201 of 8710 units - 2.31% complete
# Parsing 251 of 8710 units - 2.88% complete
# Parsing 301 of 8710 units - 3.46% complete
# Parsing 351 of 8710 units - 4.03% complete
# Parsing 401 of 8710 units - 4.60% complete
# Parsing 451 of 8710 units - 5.18% complete
# Parsing 501 of 8710 units - 5.75% complete
# Parsing 551 of 8710 units - 6.33% complete
# Parsing 601 of 8710 units - 6.90% complete
# Parsing 651 of 8710 units - 7.47% complete
# Parsing 701 of 8710 units - 8.05% complete
# Parsing 751 of 8710 units - 8.62% complete
# Parsing 801 of 8710 units - 9.20% complete
# Parsing 851 of 8710 units - 9.77% complete
# Parsing 901 of 8710 units - 10.34% complete
# Parsing 951 of 8710 units - 10.92% complete
# Parsing 1001 of 8710 units - 11.49% complete
# Parsing 1051 of 8710 units - 12.07% complete
# Parsing 1101 of 8710 units - 12.64% complete
# Parsing 1151 of 8710 units - 13.21% complete
# Parsing 1201 of 8710 units - 13.79% complete
# Parsing 1251 of 8710 units - 14.36% complete
# Parsing 1301 of 8710 units - 14.94% complete
# Parsing 1351 of 8710 units - 15.51% complete
# Parsing 1401 of 8710 units - 16.08% complete
# Parsing 1451 of 8710 units - 16.66% complete
# Parsing 1501 of 8710 units - 17.23% complete
# Parsing 1551 of 8710 units - 17.81% complete
# Parsing 1601 of 8710 units - 18.38% complete
# Parsing 1651 of 8710 units - 18.96% complete
# Parsing 1701 of 8710 units - 19.53% complete
# Parsing 1751 of 8710 units - 20.10% complete
# Parsing 1801 of 8710 units - 20.68% complete
# Parsing 1851 of 8710 units - 21.25% complete
# Parsing 1901 of 8710 units - 21.83% complete
# Parsing 1951 of 8710 units - 22.40% complete
# Parsing 2001 of 8710 units - 22.97% complete
# Parsing 2051 of 8710 units - 23.55% complete
# Parsing 2101 of 8710 units - 24.12% complete
# Parsing 2151 of 8710 units - 24.70% complete
# Parsing 2201 of 8710 units - 25.27% complete
# Parsing 2251 of 8710 units - 25.84% complete
# Parsing 2301 of 8710 units - 26.42% complete
# Parsing 2351 of 8710 units - 26.99% complete
# Parsing 2401 of 8710 units - 27.57% complete
# Parsing 2451 of 8710 units - 28.14% complete
# Parsing 2501 of 8710 units - 28.71% complete
# Parsing 2551 of 8710 units - 29.29% complete
# Parsing 2601 of 8710 units - 29.86% complete
# Parsing 2651 of 8710 units - 30.44% complete
# Parsing 2701 of 8710 units - 31.01% complete
# Parsing 2751 of 8710 units - 31.58% complete
# Parsing 2801 of 8710 units - 32.16% complete
# Parsing 2851 of 8710 units - 32.73% complete
# Parsing 2901 of 8710 units - 33.31% complete
# Parsing 2951 of 8710 units - 33.88% complete
# Parsing 3001 of 8710 units - 34.45% complete
# Parsing 3051 of 8710 units - 35.03% complete
# Parsing 3101 of 8710 units - 35.60% complete
# Parsing 3151 of 8710 units - 36.18% complete
# Parsing 3201 of 8710 units - 36.75% complete
# Parsing 3251 of 8710 units - 37.32% complete
# Parsing 3301 of 8710 units - 37.90% complete
# Parsing 3351 of 8710 units - 38.47% complete
# Parsing 3401 of 8710 units - 39.05% complete
# Parsing 3451 of 8710 units - 39.62% complete
# Parsing 3501 of 8710 units - 40.20% complete
# Parsing 3551 of 8710 units - 40.77% complete
# Parsing 3601 of 8710 units - 41.34% complete
# Parsing 3651 of 8710 units - 41.92% complete
# Parsing 3701 of 8710 units - 42.49% complete
# Parsing 3751 of 8710 units - 43.07% complete
# Parsing 3801 of 8710 units - 43.64% complete
# Parsing 3851 of 8710 units - 44.21% complete
# Parsing 3901 of 8710 units - 44.79% complete
# Parsing 3951 of 8710 units - 45.36% complete
# Parsing 4001 of 8710 units - 45.94% complete
# Parsing 4051 of 8710 units - 46.51% complete
# Parsing 4101 of 8710 units - 47.08% complete
# Parsing 4151 of 8710 units - 47.66% complete
# Parsing 4201 of 8710 units - 48.23% complete
# Parsing 4251 of 8710 units - 48.81% complete
# Parsing 4301 of 8710 units - 49.38% complete
# Parsing 4351 of 8710 units - 49.95% complete
# Parsing 4401 of 8710 units - 50.53% complete
# Parsing 4451 of 8710 units - 51.10% complete
# Parsing 4501 of 8710 units - 51.68% complete
# Parsing 4551 of 8710 units - 52.25% complete
# Parsing 4601 of 8710 units - 52.82% complete
# Parsing 4651 of 8710 units - 53.40% complete
# Parsing 4701 of 8710 units - 53.97% complete
# Parsing 4751 of 8710 units - 54.55% complete
# Parsing 4801 of 8710 units - 55.12% complete
# Parsing 4851 of 8710 units - 55.69% complete
# Parsing 4901 of 8710 units - 56.27% complete
# Parsing 4951 of 8710 units - 56.84% complete
# Parsing 5001 of 8710 units - 57.42% complete
# Parsing 5051 of 8710 units - 57.99% complete
# Parsing 5101 of 8710 units - 58.56% complete
# Parsing 5151 of 8710 units - 59.14% complete
# Parsing 5201 of 8710 units - 59.71% complete
# Parsing 5251 of 8710 units - 60.29% complete
# Parsing 5301 of 8710 units - 60.86% complete
# Parsing 5351 of 8710 units - 61.44% complete
# Parsing 5401 of 8710 units - 62.01% complete
# Parsing 5451 of 8710 units - 62.58% complete
# Parsing 5501 of 8710 units - 63.16% complete
# Parsing 5551 of 8710 units - 63.73% complete
# Parsing 5601 of 8710 units - 64.31% complete
# Parsing 5651 of 8710 units - 64.88% complete
# Parsing 5701 of 8710 units - 65.45% complete
# Parsing 5751 of 8710 units - 66.03% complete
# Parsing 5801 of 8710 units - 66.60% complete
# Parsing 5851 of 8710 units - 67.18% complete
# Parsing 5901 of 8710 units - 67.75% complete
# Parsing 5951 of 8710 units - 68.32% complete
# Parsing 6001 of 8710 units - 68.90% complete
# Parsing 6051 of 8710 units - 69.47% complete
# Parsing 6101 of 8710 units - 70.05% complete
# Parsing 6151 of 8710 units - 70.62% complete
# Parsing 6201 of 8710 units - 71.19% complete
# Parsing 6251 of 8710 units - 71.77% complete
# Parsing 6301 of 8710 units - 72.34% complete
# Parsing 6351 of 8710 units - 72.92% complete
# Parsing 6401 of 8710 units - 73.49% complete
# Parsing 6451 of 8710 units - 74.06% complete
# Parsing 6501 of 8710 units - 74.64% complete
# Parsing 6551 of 8710 units - 75.21% complete
# Parsing 6601 of 8710 units - 75.79% complete
# Parsing 6651 of 8710 units - 76.36% complete
# Parsing 6701 of 8710 units - 76.93% complete
# Parsing 6751 of 8710 units - 77.51% complete
# Parsing 6801 of 8710 units - 78.08% complete
# Parsing 6851 of 8710 units - 78.66% complete
# Parsing 6901 of 8710 units - 79.23% complete
# Parsing 6951 of 8710 units - 79.80% complete
# Parsing 7001 of 8710 units - 80.38% complete
# Parsing 7051 of 8710 units - 80.95% complete
# Parsing 7101 of 8710 units - 81.53% complete
# Parsing 7151 of 8710 units - 82.10% complete
# Parsing 7201 of 8710 units - 82.68% complete
# Parsing 7251 of 8710 units - 83.25% complete
# Parsing 7301 of 8710 units - 83.82% complete
# Parsing 7351 of 8710 units - 84.40% complete
# Parsing 7401 of 8710 units - 84.97% complete
# Parsing 7451 of 8710 units - 85.55% complete
# Parsing 7501 of 8710 units - 86.12% complete
# Parsing 7551 of 8710 units - 86.69% complete
# Parsing 7601 of 8710 units - 87.27% complete
# Parsing 7651 of 8710 units - 87.84% complete
# Parsing 7701 of 8710 units - 88.42% complete
# Parsing 7751 of 8710 units - 88.99% complete
# Parsing 7801 of 8710 units - 89.56% complete
# Parsing 7851 of 8710 units - 90.14% complete
# Parsing 7901 of 8710 units - 90.71% complete
# Parsing 7951 of 8710 units - 91.29% complete
# Parsing 8001 of 8710 units - 91.86% complete
# Parsing 8051 of 8710 units - 92.43% complete
# Parsing 8101 of 8710 units - 93.01% complete
# Parsing 8151 of 8710 units - 93.58% complete
# Parsing 8201 of 8710 units - 94.16% complete
# Parsing 8251 of 8710 units - 94.73% complete
# Parsing 8301 of 8710 units - 95.30% complete
# Parsing 8351 of 8710 units - 95.88% complete
# Parsing 8401 of 8710 units - 96.45% complete
# Parsing 8451 of 8710 units - 97.03% complete
# Parsing 8501 of 8710 units - 97.60% complete
# Parsing 8551 of 8710 units - 98.17% complete
# Parsing 8601 of 8710 units - 98.75% complete
# Parsing 8651 of 8710 units - 99.32% complete
# Parsing 8701 of 8710 units - 99.90% complete
# Data has been saved to 'datase' DataFrame

# %% [markdown]
# Dataset overview

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8710 entries, 0 to 8709
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8710 non-null   object
#  1   Class       8710 non-null   object
#  2   Variant     8645 non-null   object
#  3   Role        8693 non-null   object
#  4   PV          8710 non-null   object
#  5   Type        7649 non-null   object
#  6   Size        8710 non-null   object
#  7   Move        8710 non-null   object
#  8   Short       8710 non-null   object
#  9   ShortMin    8710 non-null   object
#  10  Medium      8710 non-null   object
#  11  MediumMin   8710 non-null   object
#  12  Long        8710 non-null   object
#  13  LongMin     8710 non-null   object
#  14  Extreme     8710 non-null   object
#  15  ExtremeMin  8710 non-null   object
#  16  Threshold   8710 non-null   object
#  17  Overheat    8710 non-null   object
#  18  Armor       8710 non-null   object
#  19  Structure   8710 non-null   object
#  20  Specials    7404 non-null   object
#  21  ImageURL    8710 non-null   object
# dtypes: object(22)
# memory usage: 1.5+ MB

# %%
dataset.nunique()
# Out:
# Name          8709
# Class         2132
# Variant       4733
# Role            15
# PV              86
# Type            18
# Size             6
# Move           200
# Short           16
# ShortMin         2
# Medium          12
# MediumMin        2
# Long            10
# LongMin          2
# Extreme          6
# ExtremeMin       2
# Threshold        6
# Overheat         5
# Armor           24
# Structure       16
# Specials      3587
# ImageURL      2009
# dtype: int64

# %% [markdown]
# Clear the dataset and make a new one (to have an access to initial data).
# All the units with 0 PV can be dropped as they shouldn't be used during a game

# %%
unitlist = dataset[dataset['PV'] != 0].reset_index(drop=True)
unitlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7654 entries, 0 to 7653
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        7654 non-null   object
#  1   Class       7654 non-null   object
#  2   Variant     7611 non-null   object
#  3   Role        7654 non-null   object
#  4   PV          7654 non-null   object
#  5   Type        7649 non-null   object
#  6   Size        7654 non-null   object
#  7   Move        7654 non-null   object
#  8   Short       7654 non-null   object
#  9   ShortMin    7654 non-null   object
#  10  Medium      7654 non-null   object
#  11  MediumMin   7654 non-null   object
#  12  Long        7654 non-null   object
#  13  LongMin     7654 non-null   object
#  14  Extreme     7654 non-null   object
#  15  ExtremeMin  7654 non-null   object
#  16  Threshold   7654 non-null   object
#  17  Overheat    7654 non-null   object
#  18  Armor       7654 non-null   object
#  19  Structure   7654 non-null   object
#  20  Specials    7401 non-null   object
#  21  ImageURL    7654 non-null   object
# dtypes: object(22)
# memory usage: 1.3+ MB

# %% [markdown]
# Check all NA values and replace them if applicable

# %%
unitlist[unitlist["Variant"].isna()].head()
# Out:
#                  Name             Class Variant          Role  PV Type Size  \
# 274  Koshi (Standard)  Koshi (Standard)    None       Striker  30   BM    1
# 482    Pack Hunter II    Pack Hunter II    None       Striker  34   BM    1
# 616         Cougar-XR         Cougar-XR    None  Missile Boat  36   BM    1
# 617             Eyrie             Eyrie    None       Striker  35   BM    1
# 655            Jaguar            Jaguar    None       Striker  42   BM    1
#
#          Move Short ShortMin  ... Long LongMin Extreme ExtremeMin Threshold  \
# 274  14"/12"j     3    False  ...    0   False       0      False         0
# 482      14"j     3    False  ...    2   False       0      False         0
# 616  10"/14"j     3    False  ...    2   False       0      False         0
# 617  12"/14"j     4    False  ...    0    True       0      False         0
# 655       16"     4    False  ...    1   False       0      False         0
#
#     Overheat Armor Structure                        Specials  \
# 274        0     2         1  CASE,JMPW1,LTAG,PRB,RCN,SRM2/2
# 482        0     3         2                            CASE
# 616        0     4         2              CASE,IF1,JMPS1,RFA
# 617        0     4         2                  CASE,JMPS1,MEL
# 655        1     4         2                 CASE,TUR(2/1/1)
#
#                                              ImageURL
# 274           https://i.ibb.co/4p5Q7X3/koshi-3150.png
# 482  https://i.ibb.co/9g5VR4J/pack-hunter-ii-3085.png
# 616            https://i.ibb.co/G9JBR33/cougar-xr.png
# 617           https://i.ibb.co/C1Gs4sr/eyrie-3145.png
# 655          https://i.ibb.co/0BTn75T/jaguar-3150.png
#
# [5 rows x 22 columns]

# %% [markdown]
# Model can be None

# %%
unitlist[unitlist["Specials"].isna()].head()
# Out:
#                    Name        Class  Variant     Role  PV Type Size  Move  \
# 13  Prey Seeker PY-SR30  Prey Seeker  PY-SR30    Scout  17   BM    1   24"
# 27        Cossack C-SK1      Cossack    C-SK1  Striker  17   BM    1  12"j
# 46      Fireball ALM-7D     Fireball   ALM-7D    Scout  17   BM    1   22"
# 47      Fireball ALM-8D     Fireball   ALM-8D    Scout  20   BM    1   22"
# 48      Fireball ALM-9D     Fireball   ALM-9D    Scout  19   BM    1   22"
#
#    Short ShortMin  ... Long LongMin Extreme ExtremeMin Threshold Overheat  \
# 13     1    False  ...    0   False       0      False         0        0
# 27     2    False  ...    0   False       0      False         0        0
# 46     1    False  ...    0   False       0      False         0        0
# 47     2    False  ...    0   False       0      False         0        0
# 48     1    False  ...    0   False       0      False         0        0
#
#    Armor Structure Specials                                       ImageURL
# 13     2         1     None  https://i.ibb.co/WkLHSR4/prey-seeker-3150.png
# 27     2         1     None      https://i.ibb.co/jhmq1pX/cossack-3060.png
# 46     2         1     None    https://i.ibb.co/p0KNM8N/fireball-3055u.png
# 47     2         1     None    https://i.ibb.co/p0KNM8N/fireball-3055u.png
# 48     2         1     None    https://i.ibb.co/p0KNM8N/fireball-3055u.png
#
# [5 rows x 22 columns]

# %% [markdown]
# Specials can be None

# %% [markdown]
# Add information for each unit about its era availability

# %%
# Define the list of eras
eras = [
    {"Name": "Star League (2571 - 2780)", "ID": "star-league"},
    {"Name": "Early Succession War (2781 - 2900)", "ID": "early-succession-war"},
    {"Name": "Late Succession War - LosTech (2901 - 3019)", "ID": "late-succession-war---lostech"},
    {"Name": "Late Succession War - Renaissance (3020 - 3049)", "ID": "late-succession-war---renaissance"},
    {"Name": "Clan Invasion (3050 - 3061)", "ID": "clan-invasion"},
    {"Name": "Civil War (3062 - 3067)", "ID": "civil-war"},
    {"Name": "Jihad (3068 - 3085)", "ID": "jihad"},
    {"Name": "Early Republic (3086 - 3100)", "ID": "early-republic"},
    {"Name": "Late Republic (3101 - 3130)", "ID": "late-republic"},
    {"Name": "Dark Ages (3131 - 3150)", "ID": "dark-age"},
    {"Name": "ilClan (3151 - 9999)", "ID": "ilclan"}
]

# Create era availabilty dataset to fill later
era_av = pd.DataFrame(columns=[era["Name"] for era in eras])

# %% [markdown]
# Fill `era_av` with units' information

# %%
# Define the URL for all battlemechs
print("start")
search_url = "http://www.masterunitlist.info/Unit/Filter?Types=18&Types=19&Types=17&Types=21&Types=20&Types=23&Types=24&Types=81&Types=79&Types=97&Types=76"

response = session.get(search_url, timeout=30)

if response.status_code != 200:
    print("Failed to retrieve unit list")
else:
    soup = BeautifulSoup(response.text, 'html.parser')
    unit_urls = [a['href'] for a in soup.find_all('a', href=True) if a['href'].startswith("/Unit/Details/")]

    def fetch_era(unit_url):
        unit_details_url = f"http://www.masterunitlist.info{unit_url}"
        unit_response = session.get(unit_details_url, timeout=30)
        unit_soup = BeautifulSoup(unit_response.text, 'html.parser')

        unit_era = {'Name': unit_soup.find("h2").get_text().strip()}
        for era in eras:
            faction_era_element = unit_soup.find(id=era["ID"])
            if faction_era_element is not None:
                factions = [a.get_text().strip() for a in faction_era_element.find_all("a")]
                unit_era[era["Name"]] = ", ".join(factions)
            else:
                unit_era[era["Name"]] = "Unknown"
        return unit_era

    results = []
    with ThreadPoolExecutor(max_workers=10) as executor:
        futures = {executor.submit(fetch_era, url): url for url in unit_urls}
        for future in tqdm(as_completed(futures), total=len(futures)):
            try:
                results.append(future.result())
            except Exception as e:
                print(f"Error fetching {futures[future]}: {e}")

    era_av = pd.DataFrame(results)
    print(f"Data has been saved to 'era_av' dataset")
# Out:
# start
#   0%|          | 0/8710 [00:00<?, ?it/s]
# Error fetching /Unit/Details/4923/rising-star-rst-4r: HTTPConnectionPool(host='www.masterunitlist.info', port=80): Max retries exceeded with url: /Unit/Details/4923/rising-star-rst-4r (Caused by ReadTimeoutError("HTTPConnectionPool(host='www.masterunitlist.info', port=80): Read timed out. (read timeout=30)"))
# Data has been saved to 'era_av' dataset

# %%
era_av.head()
# Out:
#                  Name Star League (2571 - 2780)  \
# 0              Daemon                   Unknown
# 1  Celerity CLR-03-OA                   Unknown
# 2       Stinger LAM C                   Unknown
# 3  Celerity CLR-03-OC                   Unknown
# 4  Celerity CLR-03-OD                   Unknown
#
#   Early Succession War (2781 - 2900)  \
# 0                            Unknown
# 1                            Unknown
# 2                            Unknown
# 3                            Unknown
# 4                            Unknown
#
#   Late Succession War - LosTech (2901 - 3019)  \
# 0                                     Unknown
# 1                                     Unknown
# 2                                     Unknown
# 3                                     Unknown
# 4                                     Unknown
#
#   Late Succession War - Renaissance (3020 - 3049) Clan Invasion (3050 - 3061)  \
# 0                                         Unknown                     Unknown
# 1                                         Unknown                     Unknown
# 2                                         Unknown    Clan Jade Falcon, Unique
# 3                                         Unknown                     Unknown
# 4                                         Unknown                     Unknown
#
#   Civil War (3062 - 3067) Jihad (3068 - 3085) Early Republic (3086 - 3100)  \
# 0                 Unknown             Unknown                      Unknown
# 1                 Unknown             Unknown                      Unknown
# 2                 Extinct             Extinct                      Extinct
# 3                 Unknown             Unknown                      Unknown
# 4                 Unknown             Unknown                      Unknown
#
#   Late Republic (3101 - 3130) Dark Ages (3131 - 3150) ilClan (3151 - 9999)
# 0                     Unknown                 Unknown              Unknown
# 1                     Unknown  Republic of the Sphere            Mercenary
# 2                     Extinct                 Extinct              Extinct
# 3                     Unknown  Republic of the Sphere            Mercenary
# 4                     Unknown  Republic of the Sphere            Mercenary

# %% [markdown]
# Join both datasets to get final one:

# %%
unitlist = unitlist.join(era_av.set_index('Name'), on='Name', how="left")
unitlist.head()
# Out:
#                   Name     Class     Variant   Role  PV Type Size Move Short  \
# 0  Celerity CLR-02-X-D  Celerity  CLR-02-X-D  Scout  15   BM    1  40"     0
# 1    Celerity CLR-03-O  Celerity    CLR-03-O  Scout  15   BM    1  40"     0
# 2   Celerity CLR-03-OA  Celerity   CLR-03-OA  Scout  16   BM    1  40"     0
# 3   Celerity CLR-03-OB  Celerity   CLR-03-OB  Scout  16   BM    1  40"     0
# 4   Celerity CLR-03-OC  Celerity   CLR-03-OC  Scout  16   BM    1  40"     0
#
#   ShortMin  ... Early Succession War (2781 - 2900)  \
# 0    False  ...                            Unknown
# 1    False  ...                            Unknown
# 2     True  ...                            Unknown
# 3    False  ...                            Unknown
# 4    False  ...                            Unknown
#
#   Late Succession War - LosTech (2901 - 3019)  \
# 0                                     Unknown
# 1                                     Unknown
# 2                                     Unknown
# 3                                     Unknown
# 4                                     Unknown
#
#   Late Succession War - Renaissance (3020 - 3049) Clan Invasion (3050 - 3061)  \
# 0                                         Unknown                     ComStar
# 1                                         Unknown                     Unknown
# 2                                         Unknown                     Unknown
# 3                                         Unknown                     Unknown
# 4                                         Unknown                     Unknown
#
#   Civil War (3062 - 3067) Jihad (3068 - 3085) Early Republic (3086 - 3100)  \
# 0                 ComStar             ComStar                      Extinct
# 1                 Unknown             Unknown                      Unknown
# 2                 Unknown             Unknown                      Unknown
# 3                 Unknown             Unknown                      Unknown
# 4                 Unknown             Unknown                      Unknown
#
#   Late Republic (3101 - 3130) Dark Ages (3131 - 3150) ilClan (3151 - 9999)
# 0                     Extinct                 Extinct              Extinct
# 1                     Unknown  Republic of the Sphere            Mercenary
# 2                     Unknown  Republic of the Sphere            Mercenary
# 3                     Unknown  Republic of the Sphere            Mercenary
# 4                     Unknown  Republic of the Sphere            Mercenary
#
# [5 rows x 33 columns]

# %% [markdown]
# Write dataset into csv file:

# %%
path = f"unit_list.csv"
unitlist.to_csv(path, index=False)
print("done")
# Out:
# done
